# %%
import sys, os
import pickle
import time 
import random

# TO CHANGE
BASEDIR = "../../../"
sys.path.insert(0, BASEDIR)

__import__('pysqlite3')
sys.modules['sqlite3'] = sys.modules.pop('pysqlite3')

# %%
TRIALS = 2
FIX_FILE_PATH = "./import_fix.py"
for _ in range(TRIALS):
    try:
      from src import PersonalAI, PersonalAIConfig, QAPipelineConfig, MemPipelineConfig, \
            GraphModelConfig, EmbeddingsModelConfig, EmbedderModelConfig
      from src.db_drivers import KeyValueDriverConfig, GraphDriverConfig, VectorDriverConfig
      from src.db_drivers.kv_driver import DEFAULT_INMEMORYKV_CONFIG
      from src.db_drivers.graph_driver import DEFAULT_INMEMORYGRAPH_CONFIG, DEFAULT_KUZU_CONFIG
      from src.db_drivers.vector_driver import VectorDBConnectionConfig

      from src.qa_pipeline.knowledge_retriever import AStarGraphSearchConfig, AStarMetricsConfig, BFSSearchConfig, MixturedGraphSearchConfig
      from src.qa_pipeline import QueryLLMParserConfig, KnowledgeComparatorConfig, KnowledgeRetrieverConfig, QALLMGeneratorConfig

      from src.memorize_pipeline import LLMExtractorConfig, LLMUpdatorConfig

      from src.utils import NodeType, Logger
    except RuntimeError as e:
        from pathlib import Path
        fix_path = Path(FIX_FILE_PATH)
        if fix_path.is_file():
            # %run {fix_path} --base_dir BASEDIR
        else:
            raise e
# Out:
# /app/distrib_manual/jupiter/venv/lib64/python3.9/site-packages/sentence_transformers/cross_encoder/CrossEncoder.py:13: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange

# %% [markdown]
# #### 1. Загружем датасет с триплетами, на основе которого будет построен граф знаний

# %%
base_path = './meta'
PKL_GRAPH_PATH = os.path.join(base_path, 'all_triplets_max.pkl')

with open(PKL_GRAPH_PATH, 'rb') as f:
    formated_triplets = pickle.load(f)

# %%
length = 211542
print(len(formated_triplets))
formated_triplets = formated_triplets[:length]
print(len(formated_triplets))
# Out:
# 46041
# 46041

# %% [markdown]
# #### 2. Задаём конфигурацию графа знаний

# %%
# in-memory storage
# kuzu - test instead of inmemory_graph; download new code from github
# GRAPH_STORAGE_CONFIG = GraphDriverConfig(db_vendor='inmemory_graph', db_config=DEFAULT_INMEMORYGRAPH_CONFIG)
GRAPH_STORAGE_CONFIG = GraphDriverConfig(db_vendor='kuzu', db_config=DEFAULT_KUZU_CONFIG)
GRAPH_MODEL_CONFIG = GraphModelConfig(driver_config=GRAPH_STORAGE_CONFIG, verbose=True)
KV_STORAGE_CONFIG = KeyValueDriverConfig(db_vendor='inmemory_kv', db_config=DEFAULT_INMEMORYKV_CONFIG) # left as is

# %%
# Vector model configuration
NODES_DB_PATH = '../../../data/graph_structures/vectorized_nodes/testing' # TO CHANGE
TRIPLETS_DB_PATH = '../../../data/graph_structures/vectorized_triplets/testing' # TO CHANGE
NEED_TO_CLEAR = True

VECTOR_NODES_STORAGE_CONFIG = VectorDriverConfig(db_config=VectorDBConnectionConfig(path=NODES_DB_PATH, need_to_clear=NEED_TO_CLEAR))
VECTOR_TRIPLETS_STIRAGE_CONFIG = VectorDriverConfig(db_config=VectorDBConnectionConfig(path=TRIPLETS_DB_PATH, need_to_clear=NEED_TO_CLEAR))

DEVICE = 'cuda' # TO CHANGE
EMBEDDER_MODEL_PATH = "/app/distrib/isu-top-question-answer/src/gigasum/multilingual-e5-large"
EMBEDDER_MODEL_CONFIG = EmbedderModelConfig(model_name_or_path=EMBEDDER_MODEL_PATH, device=DEVICE)

VECTOR_MODEL_CONFIG = EmbeddingsModelConfig(
    nodesdb_driver_config=VECTOR_NODES_STORAGE_CONFIG,
    tripletsdb_driver_config=VECTOR_TRIPLETS_STIRAGE_CONFIG,
    embedder_config=EMBEDDER_MODEL_CONFIG)

# %%
# QA-pipeline retrieve stage configuration (configuring mixture graph search/retriever)
# max_passed_nodes - кол-во пройденных нод (-1 - скоко угодно), см. доку
# strict_filter=False - для QA лучше будет

# ASTAR_RETRIEVER_CONFIG = AStarGraphSearchConfig()
# BFS_RETRIEVER_CONFIG = BFSSearchConfig()

ASTAR_RETRIEVER_CONFIG = AStarGraphSearchConfig(
    metrics_config=AStarMetricsConfig(h_metric_name='ip', kvdriver_config=KV_STORAGE_CONFIG),
    max_depth=20, max_passed_nodes=1000,
    accepted_node_types=[NodeType.object , NodeType.hyper, NodeType.episodic])

BFS_RETRIEVER_CONFIG = BFSSearchConfig(
    strict_filter = True, hyper_episodic_num = 15,
    chain_triplets_num = 25, other_triplets_num = 6)

RETRIEVER_NAME = 'mixture'
RETRIEVER_CONFIG = MixturedGraphSearchConfig(
    astar_config=ASTAR_RETRIEVER_CONFIG,
    bfs_config=BFS_RETRIEVER_CONFIG
)

# %%
LANGUAGE = 'ru' # TO CHANGE ('ru' | 'en' | 'auto')

# QA-pipeline configuration
QA_PIPELINE_CONFIG = QAPipelineConfig(
    query_parser_config=QueryLLMParserConfig(lang=LANGUAGE),
    knowledge_comparator_config=KnowledgeComparatorConfig(),
    knowledge_retriever_config=KnowledgeRetrieverConfig(
        retriever_method=RETRIEVER_NAME,retriever_config=RETRIEVER_CONFIG),
    answer_generator_config=QALLMGeneratorConfig(lang=LANGUAGE))

# Memorize-pipeline configuration
MEM_PIPELINE_CONFIG = MemPipelineConfig(
    extractor_config=LLMExtractorConfig(lang=LANGUAGE),
    updator_config=LLMUpdatorConfig(lang=LANGUAGE))

PERSONALAI_CONFIG = PersonalAIConfig(
    graph_struct_config=GRAPH_MODEL_CONFIG,
    embedds_struct_config=VECTOR_MODEL_CONFIG,
    qa_pipeline_config=QA_PIPELINE_CONFIG,
    mem_pipeline_config=MEM_PIPELINE_CONFIG,
    log=Logger('log/main'))

# %% [markdown]
# #### 3. Инициализируем граф знаний

# %%
personalai = PersonalAI(config=PERSONALAI_CONFIG)
# Out:
# warning: graph-dump '../../kuzu_volume/default_db' doesnt exists. creating empty graph-store

# %%
# ATTENTION !!!
#rkg_main.kg_model.graph_struct.db_conn.execute_query("match (a) -[r] -> () delete a, r")
#rkg_main.kg_model.graph_struct.db_conn.execute_query("match (a) delete a")
# ATTENTION !!!

# %% [markdown]
# #### 4. Добавляем в граф загруженные триплеты

# %%
print("uploading data to graph-storage")
graph_info = personalai.kg_model.graph_struct.create_triplets(formated_triplets)
# graph_info
# Out:
# uploading data to graph-storage
# Adding triplets to graph-model...
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 720/720 [02:57<00:00,  4.05it/s]
# all/unique/existed triplets - 46041/11034/0
# all/unique/existed nodes - 92082/13519/0
# Triplets added successfully!

# %%
print("uploading data to vector-storage")
vector_info = personalai.kg_model.embeddings_struct.create_triplets(formated_triplets)
# Out:
# uploading data to vector-storage
#  30%|███████████████████████████████████                                                                                 | 109/360 [01:17<02:48,  1.49it/s]

# %% [markdown]
# #### 5. Q&A - Compare with SberQA

# %%
import pandas as pd
import json

questions_df = pd.read_excel('./meta/questions.xlsx')
questions = questions_df.to_dict()

# selected_questions_idx = [14,15,16,17,18,22,23,27,28,30]

# %%
with open("./meta/doc_data.jsonl", 'r', encoding='utf-8') as fd:
    data = [json.loads(line) for line in fd]
    
set_doc_names = set()
for d in data:
    set_doc_names.add(d['doc_name'])
    
if PKL_GRAPH_PATH.endswith('pro.pkl'):
    prediction_column = 'pro_triplet_giga'
else:
    prediction_column = 'max_triplet_giga'

answers = []
infos = []
count_of_q = len(questions['question'])

# %%
for k in range(count_of_q):
# for k in selected_questions_idx:
    if questions['doc_name'][k] not in set_doc_names:
        print(f'Skipped {questions["doc_name"][k]} !!!')
        continue
    q = questions['question'][k]
    ans = questions['answer'][k]
    qa_giga_max_predict = questions['GigaChatMax_predict'][k]  # our qa
    qa_giga_pro_predict = questions['GigaChatPro_predict'][k]  # our qa

    answer, info = personalai.answer_question(q)
    answers.append(answer)
    infos.append(info)

    print(f"Question: {q} | \nGolden answer: {ans} | \nGraph Answer: {answer} | \nQA Answer GigaPro: {qa_giga_pro_predict}\n")
    print(10*"=====")

# questions_df[prediction_column] = answers
# questions_df.to_excel("./meta/questions.xlsx")
# Out:
# Question: Сколько активных корпоративных клиентов ? |
# Golden answer: Согласно отчету за 2023 год насчитывается 3,2 миллиона активных копроративных клиентов. |
# Graph Answer: None |
# QA Answer GigaPro: У Сбера 3,2 миллиона активных корпоративных клиентов.
#
# ==================================================
# Question: Найди коэффицент CET1 по итогам 23 года |
# Golden answer: CET1 или коэффицент достаточности базового капитала 1-го уровня составил 13,2 % по итогам 2023 года |
# Graph Answer: None |
# QA Answer GigaPro: Коэффициент достаточности базового капитала 1-го уровня (CET1) по итогам 2023 года составил 13,2%.
#
# ==================================================
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 11
#       8 qa_giga_max_predict = questions['GigaChatMax_predict'][k]  # our qa
#       9 qa_giga_pro_predict = questions['GigaChatPro_predict'][k]  # our qa
# ---> 11 answer, info = personalai.answer_question(q)
#      12 answers.append(answer)
#      13 infos.append(info)
#
# File /app/jupyter_root/AICRND/PersonalAI/Personal-AI-test-new/notebooks/evaluation/my_tests/../../../src/personalai_main.py:64, in PersonalAI.answer_question(self, question)
#      62 self.log("Start answer generation:", verbose=self.config.verbose)
#      63 self.log(f"\t- question: {question}", verbose=self.config.verbose)
# ---> 64 answer, info = self.qa_pipeline.answer(question)
#      65 self.log(f"\t- answer: {answer}", verbose=self.config.verbose)
#      66 return answer, info
#
# File /app/jupyter_root/AICRND/PersonalAI/Personal-AI-test-new/notebooks/evaluation/my_tests/../../../src/qa_pipeline/QAPipeline.py:75, in QAPipeline.answer(self, query)
#      73 if info.status == ReturnStatus.success:
#      74     self.log("==="*4 + "STAGE#3 - retrieve" + "==="*4, verbose=self.config.verbose)
# ---> 75     retrieved_triplets, info = self.knowledge_retriever.retrieve(query_info)
#      76     #self.log(f"RETRIEVED_TRIPLES:\n {retrieved_triplets}", verbose=self.config.verbose)
#      78 if info.status == ReturnStatus.success:
#
# File /app/jupyter_root/AICRND/PersonalAI/Personal-AI-test-new/notebooks/evaluation/my_tests/../../../src/qa_pipeline/knowledge_retriever/KnowledgeRetriever.py:79, in KnowledgeRetriever.retrieve(self, query_info)
#      77 info = ReturnInfo()
#      78 self.log("stage #3.1 - extracting triplets...", verbose=self.config.verbose)
# ---> 79 triplets = self.graph_retriever.get_relevant_triplets(query_info)
#      80 self.log(f"Количество извлечённых триплетов: {len(triplets)}", verbose=self.config.verbose)
#      82 self.log("stage #3.2 - filtering triplets...", verbose=self.config.verbose)
#
# File /app/jupyter_root/AICRND/PersonalAI/Personal-AI-test-new/notebooks/evaluation/my_tests/../../../src/qa_pipeline/knowledge_retriever/MixturedTripletsRetriever.py:46, in MixturedTripletsRetriever.get_relevant_triplets(self, query_info)
#      45 def get_relevant_triplets(self, query_info: QueryInfo) -> List[Triplet]:
# ---> 46     astar_triplets = self.astar_searcher.get_relevant_triplets(query_info)
#      47     bfs_triplets = self.bfs_searcher.get_relevant_triplets(query_info)
#      49     self.log(f"Количество триплетов, извлечённых с помощью A*/BFS: {len(astar_triplets)}/{len(bfs_triplets)}",
#      50              verbose=self.verbose)
#
# File /app/jupyter_root/AICRND/PersonalAI/Personal-AI-test-new/notebooks/evaluation/my_tests/../../../src/qa_pipeline/knowledge_retriever/AStarTripletsRetriever.py:363, in AStarTripletsRetriever.get_relevant_triplets(self, query_info)
#     361 unique_triplets = dict()
#     362 for nodes_pair in unique_nodes_pairs:
# --> 363     triplets = self.kg_model.graph_struct.db_conn.get_triplets(*nodes_pair)
#     364     for triplet in triplets:
#     365         unique_triplets[triplet.relation.id] = triplet
#
# File /app/jupyter_root/AICRND/PersonalAI/Personal-AI-test-new/notebooks/evaluation/my_tests/../../../src/db_drivers/graph_driver/connectors/KuzuConnector.py:194, in KuzuConnector.get_triplets(self, node1_id, node2_id)
#     189     raise ValueError
#     191 output = self.conn.execute(
#     192     f'MATCH (n1)-[rel]-(n2) WHERE n1.str_id = "{node1_id}" AND n2.str_id = "{node2_id}" RETURN n1, rel, n2;')
# --> 194 formated_triplets = self.parse_query_output(output)
#     195 unique_triplets = {triplet.id: triplet for triplet in formated_triplets}
#     196 return list(unique_triplets.values())
#
# File /app/jupyter_root/AICRND/PersonalAI/Personal-AI-test-new/notebooks/evaluation/my_tests/../../../src/db_drivers/graph_driver/connectors/KuzuConnector.py:139, in KuzuConnector.parse_query_output(self, output)
#     137 n1_type = self.config.params['table_type_map']['nodes']['inverse'][cur_n1['_label']]
#     138 n2_type = self.config.params['table_type_map']['nodes']['inverse'][cur_n2['_label']]
# --> 139 rel_type = self.config.params['table_type_map']['relations']['inverse'][cur_rel['_label']]
#     141 node1 = Node(id=cur_n1['str_id'], name=str(cur_n1['name']),
#     142              type=NODES_TYPES_MAP[n1_type], prop=dict(cur_n1['prop']))
#     143 node2 = Node(id=cur_n2['str_id'], name=str(cur_n2['name']),
#     144              type=NODES_TYPES_MAP[n2_type], prop=dict(cur_n2['prop']))
#
# KeyError: 'episodic_rel_object_episodic'

# %%
personalai.kg_model.graph_struct.

# %%
answers
# 0,1,3,5,7

# %%
infos
# Out:
# [ReturnInfo(occurred_warning=[], status=<ReturnStatus.zero_retrieved_triplets: 7>, message='Было извлечено ноль триплетов из используемого графа знаний.'),
#  ReturnInfo(occurred_warning=[], status=<ReturnStatus.zero_retrieved_triplets: 7>, message='Было извлечено ноль триплетов из используемого графа знаний.')]

# %% [markdown]
# #### 5. Print them all - Old version - прогон старой версии Personal-Ai-test

# %%
questions_df = pd.read_excel('./meta/questions-old-version.xlsx')
questions = questions_df.to_dict()

answers = []
count_of_q = len(questions['question'])

from IPython.display import clear_output

def ask_graph_questions(questions):
    total_output = ""
    n_lines = 15
    printed_lines = 0
    for i in range(n_lines - printed_lines):
        print()

    for k in range(count_of_q):
        if k not in [0, 2, 4]:
            continue
        
        if questions['doc_name'][k] not in set_doc_names:
            print(f'Skipped {questions["doc_name"][k]} !!!')
            continue
        q = questions['question'][k]
        ans = questions['answer'][k]

        total_output += f"\033[1mQuestion:\033[0m {q}\n"
        printed_lines += 1 
        clear_output(wait=True)
        print(total_output)
        for i in range(n_lines - printed_lines):
            print()
        time.sleep(random.randint(2, 4))

        qa_giga_max_predict = questions['GigaChatMax_predict'][k]  # our qa
        qa_giga_pro_predict = questions['GigaChatPro_predict'][k]  # our qa
    
        pro_triplet_giga = questions['pro_triplet_giga'][k]  # our qa
        max_triplet_giga = questions['max_triplet_giga'][k]  # our qa
        # print(f"\033[1mQuestion:\033[0m {q} | \n\033[1mGolden answer:\033[0m {ans} | \n\033[1mPro Graph Answer:\033[0m {pro_triplet_giga} | \n\033[1mMax Graph Answer:\033[0m {max_triplet_giga} | \n\033[1mQA Answer GigaPro:\033[0m {qa_giga_pro_predict}\n")
        total_output += f"\033[1mTrue answer:\033[0m {ans} | \n\033[1mGraph Answer:\033[0m {max_triplet_giga} \n" + 10*"=====" + "\n"
        printed_lines += (f"\033[1mTrue answer:\033[0m {ans} | \n\033[1mGraph Answer:\033[0m {max_triplet_giga} \n" + 10*"=====" + "\n").count('\n') + 1

        clear_output(wait=True)
        print(total_output)
        for i in range(n_lines - printed_lines):
            print()

# %%
ask_graph_questions(questions)
# Out:
# Question: Сколько активных корпоративных клиентов ?
# True answer: Согласно отчету за 2023 год насчитывается 3,2 миллиона активных копроративных клиентов. |
# Graph Answer: 3,2 миллиона активных корпоративных клиентов.
# ==================================================
# Question: Какую награду присудило агентство нильсон репорт ?
# True answer: Агентство Nilson Report присудило две награды: #1 эквайер в Европе, #3 эквайер в мире. |
# Graph Answer: Агентство Nilson Report присудило следующие награды:
# - № 3 эквайер в мире;
# - № 1 эквайер в Европе.
# ==================================================
# Question: Какова доля Сбербанка в сегменте средств частных клиентов ?
# True answer: За 2023 год доля средств частных клиентов составила 43,9% |
# Graph Answer: Доля Сбербанка в сегменте средств частных клиентов составляет 43,9%.
# ==================================================

# %%
16, count_of_q
# Out:
# (16, 31)

# %% [markdown]
# #### 5. Print them all - New version - прогон новой версии Personal-Ai-test-new (ответы хуже)
# вероятно надо пересобрать граф на новой версии и еще раз посмотреть ответы

# %%
questions_df = pd.read_excel('./meta/questions.xlsx')
questions = questions_df.to_dict()

answers = []
count_of_q = len(questions['question'])
for k in range(count_of_q):
    if questions['doc_name'][k] not in set_doc_names:
        print(f'Skipped {questions["doc_name"][k]} !!!')
        continue
    q = questions['question'][k]
    ans = questions['answer'][k]
    qa_giga_max_predict = questions['GigaChatMax_predict'][k]  # our qa
    qa_giga_pro_predict = questions['GigaChatPro_predict'][k]  # our qa

    pro_triplet_giga = questions['pro_triplet_giga'][k]  # our qa
    max_triplet_giga = questions['max_triplet_giga'][k]  # our qa
    print(f"\033[1mQuestion:\033[0m {q} | \n\033[1mGolden answer:\033[0m {ans} | \n\033[1mPro Graph Answer:\033[0m {pro_triplet_giga} | \n\033[1mMax Graph Answer:\033[0m {max_triplet_giga} | \n\033[1mQA Answer GigaPro:\033[0m {qa_giga_pro_predict}\n")
    print(10*"=====")
# Out:
# Question: Сколько активных корпоративных клиентов ? |
# Golden answer: Согласно отчету за 2023 год насчитывается 3,2 миллиона активных копроративных клиентов. |
# Pro Graph Answer: nan |
# Max Graph Answer: nan |
# QA Answer GigaPro: У Сбера 3,2 миллиона активных корпоративных клиентов.
#
# ==================================================
# Question: Найди коэффицент CET1 по итогам 23 года |
# Golden answer: CET1 или коэффицент достаточности базового капитала 1-го уровня составил 13,2 % по итогам 2023 года |
# Pro Graph Answer: nan |
# Max Graph Answer: nan |
# QA Answer GigaPro: Коэффициент достаточности базового капитала 1-го уровня (CET1) по итогам 2023 года составил 13,2%.
#
# ==================================================
# Question: Какую награду присудило агентство нильсон репорт ? |
# Golden answer: Агентство Nilson Report присудило две награды: #1 эквайер в Европе, #3 эквайер в мире. |
# Pro Graph Answer: Информация не содержит данных о награде, присужденной агентством Nilson Report. |
# Max Graph Answer: На основании предоставленной информации невозможно ответить на поставленный вопрос. |
# QA Answer GigaPro: Агентство Nilson Report присудило награду "№ 3 эквайер в мире" и "№ 1 эквайер в Европе".
#
# ==================================================
# Question: Насколько вырос показатель CSI в процентах? |
# Golden answer: Индекс удовлетворенности клиентов (CSI) вырос на 1,2 процентный пункт, и составил 81,2%. |
# Pro Graph Answer: На основе предоставленной информации невозможно определить, насколько вырос показатель CSI в процентах. |
# Max Graph Answer: nan |
# QA Answer GigaPro: В предоставленном контексте нет информации о показателе CSI (Customer Satisfaction Index) и его росте в процентах.
#
# ==================================================
# Question: Какова доля Сбербанка в сегменте средств частных клиентов ? |
# Golden answer: За 2023 год доля средств частных клиентов составила 43,9% |
# Pro Graph Answer: Доля Сбербанка в сегменте средств частных клиентов не указана в предоставленной информации. |
# Max Graph Answer: Доля Сбербанка в сегменте средств частных клиентов составляет 52,3% в 2023 году (100% - 47,7%). |
# QA Answer GigaPro: Доля Сбербанка в сегменте средств частных клиентов составляет 43,9%.
#
# ==================================================
# Question: Найди основные показатели по потребительскому кредитованию |
# Golden answer: По итогам 2023 года объем выданных потребительских кредитов составил 3,2 трлн руб, что в 1,5 раза больше чем за предыдущий год. Остаток портфеля - 3,9 трлн руб, что на 10,9% больше чем за 2022 год. Доля выданных кредитов в СберБанк Онлайн - 94%. Доля Сбера на рынке потребительских кредитов - 39,4%, что на 1,7 п.п. больше чем за 2022 год. |
# Pro Graph Answer: nan |
# Max Graph Answer: nan |
# QA Answer GigaPro: Основные показатели по потребительскому кредитованию из предоставленного контекста:
# - Остаток портфеля потребительских кредитов составляет 3,9 трлн рублей.
# - Доля Сбера на рынке потребительских кредитов по данным Банка России составляет 39,4%.
# - Объем выданных потребительских кредитов за 2023 год составил 3,2 трлн рублей.
#
# ==================================================
# Question: Как изменилась доля Сбера в брокерском обслуживании с 2022 по 2023 год |
# Golden answer: Упала на 1,3 п.п. с 19,1% до 17,8% |
# Pro Graph Answer: Из предоставленной информации нельзя сделать вывод о том, как изменилась доля Сбера в брокерском обслуживании с 2022 по 2023 год. |
# Max Graph Answer: Доля Сбера в брокерском обслуживании снизилась на 1,3 процентных пункта с 2022 по 2023 год. |
# QA Answer GigaPro: Доля Сбера в брокерском обслуживании с 2022 по 2023 год уменьшилась на 1,3 процентных пункта.
#
# ==================================================
# Question: Назови нововведения по теме финансового планирования в сегменте B2C |
# Golden answer: За 2023 год был запущен сервис "Финансовое здоровье" для премиальных клиентов. Дообучили "Финансового советника", который позволит  более детально анализировать траты клиентов. В сервис "Анализ финансов" добавлен раздел с ближайшими платежами. На главной в СберБанк онлайн добавили новый рзадел с расходами клиента. |
# Pro Graph Answer: В сегменте B2C в области финансового планирования были внедрены следующие нововведения:
#
# 1. Клиенты Сбербанка активно пользуются сервисом персонального финансового планирования через платформу Сбербанк Онлайн.
# 2. Доля пользователей этого сервиса составляет 94,0% от общего числа клиентов банка.
# 3. Ежедневная аудитория сервисов персонального финансового планирования составляет 21,6 млн человек, что демонстрирует рост на 78% по сравнению с предыдущим годом. |
# Max Graph Answer: nan |
# QA Answer GigaPro: Нововведения по теме финансового планирования в сегменте B2C включают:
#
# 1. Запуск нового сервиса "Финансовое здоровье" в мобильном приложении СберБанк Онлайн, который доступен для клиентов премиальных каналов обслуживания (СберПервый и СберПремьер). Этот сервис помогает комплексно оценивать эффективность управления финансами, подталкивая пользователей к регулярному контролю расходов, формированию финансовой подушки, защите релевантных областей рисков и сбалансированности инвестиционного портфеля.
#
# 2. Разработку виртуального ассистента Салют, который обучен анализировать траты клиентов и предоставляет им информацию о расходах в конкретных магазинах или по конкретным операциям. Виртуальный ассистент также предлагает контекстные подсказки по получению налогового вычета и возможностям компенсации трат на ЖКХ, мобильную связь и кредиты с помощью бонусов "Спасибо".
#
# 3. Добавление раздела с ближайшими платежами текущего месяца в сервис "Анализ финансов", который подсвечивает, когда и сколько нужно заплатить по кредитам, кредитной карте, автоплатежам и другим обязательным тратам.
#
# 4. Вывод нового раздела с расходами клиента на главный экран мобильного приложения СберБанк Онлайн. Этот раздел показывает, сколько денег уже потрачено в текущем месяце и на какие категории, а также сколько денег еще можно потратить из запланированного бюджета, помогая регулярно следовать намеченному плану и не тратить лишнего.
#
# ==================================================
# Question: Какой прогноз НКР присвоило СберБанку в 2023 году ? |
# Golden answer: 19 октября 2023 года рейтинговое агентство "Национальные кредитные рейтинги" присвоило стабильный прогноз. |
# Pro Graph Answer: В 2023 году Национальное Кредитное Рейтинговое Агентство (НКР) присвоило СберБанку стабильный прогноз. |
# Max Graph Answer: Прогноз НКР присвоила Сбербанку в 2023 году наивысший кредитный рейтинг по национальной шкале — AAA.RU. |
# QA Answer GigaPro: В 2023 году рейтинговое агентство "Национальные Кредитные Рейтинги" (НКР) присвоило СберБанку стабильный прогноз к кредитному рейтингу AAA.ru.
#
# ==================================================
# Question: Найди чистый доход от комиссий за 2023 год  |
# Golden answer: Чистый комиссионный доход за 2023 год составил 763,9 млрд рублей. |
# Pro Graph Answer: Чистый доход от комиссий за 2023 год составляет 10 миллионов рублей. |
# Max Graph Answer: Чистый доход от комиссий за 2023 год составляет 764 млрд рублей. |
# QA Answer GigaPro: Чистый доход от комиссий за 2023 год составил 763,9 млрд рублей.
#
# ==================================================
# Question: Найди показатели рентабельности, которые показали отрицательную динамику |
# Golden answer: Согласно финансовым показателям за 2023 год, графа операционные расходы к операционному доходу до резервов (CIR) изменилась на -9 п.п. с 2022 по 2023 год. |
# Pro Graph Answer: nan |
# Max Graph Answer: На основании предоставленной информации невозможно определить, какие показатели рентабельности показали отрицательную динамику, так как в ней указано, что "уровень рентабельности сохранения высокий". |
# QA Answer GigaPro: Рентабельность среднегодовых активов (ROA) снизилась на 2,5 п.п., с 3,3% в 2021 году до 3,2% в 2023 году. Отношение кредитов и авансов клиентам после вычета резервов под кредитные убытки к средствам физических лиц и корпоративных клиентов также уменьшилось на 4,1 п.п. между 2022 и 2023 годами.
#
# ==================================================
# Question: Для чего нужен gigacode ? |
# Golden answer: Данный сервис предназначен для ускорения написания кода, что позволяет потенциально сократить время разработки ПО на 25% |
# Pro Graph Answer: nan |
# Max Graph Answer: nan |
# QA Answer GigaPro: GigaCode используется для сокращения времени разработчиков на создание и совершенствование продуктов. Он позволяет автодополнять и генерировать программный код, что помогает ускорить производственный процесс.
#
# ==================================================
# Question: Назови функции комитета по кадрам и вознаграждениям |
# Golden answer: Основные функции - формирование программ адаптации и профессонального развития членов Наб. совета, контроль за реализацией этих программ. |
# Pro Graph Answer: Функции комитета по кадрам и вознаграждениям включают управление рисками, связанными с нехваткой персонала, высокой текучестью кадров, недостаточной профессиональной подготовкой сотрудников и общим отсутствием мотивации. |
# Max Graph Answer: Комитет по кадрам и вознаграждениям выполняет следующие функции:
# - Управление кадровыми вопросами компании;
# - Разработка и реализация программ мотивации сотрудников;
# - Контроль за соблюдением корпоративных стандартов в области вознаграждений;
# - Оценка эффективности работы персонала;
# - Обеспечение справедливого распределения вознаграждений среди сотрудников. |
# QA Answer GigaPro: Функции комитета по кадрам и вознаграждениям включают:
# 1. Формирование эффективной системы вознаграждения членов Наблюдательного совета, исполнительных органов Банка и иных ключевых руководящих работников.
# 2. Подготовка предложений по формированию программ адаптации и профессионального развития членов Наблюдательного совета с учетом их индивидуальных потребностей.
# 3. Контроль за практической реализацией программ адаптации и профессионального развития.
# 4. Регулярная оценка деятельности членов исполнительных органов Банка, включая учет ESG-показателей (экологических, социальных и управленческих).
# 5. Подготовка рекомендаций по кандидатуре куратора по вопросам ESG и устойчивого развития из состава Наблюдательного совета.
#
# ==================================================
# Question: Назови задачи комитета по кадрам и вознаграждениям |
# Golden answer: Это усиление кадрового состава и повышение эффективности работы Наблюдательного совета, а также подготовка предложений по формированию эффективной системы вознаграждения ключевых руководящих работников. |
# Pro Graph Answer: Задачи комитета по кадрам и вознаграждениям включают управление рисками, связанными с нехваткой персонала, высокой текучестью кадров, недостаточной профессиональной подготовкой сотрудников и общим отсутствием мотивации. |
# Max Graph Answer: Задачи комитета по кадрам и вознаграждениям не указаны в предоставленной информации. |
# QA Answer GigaPro: Задачи комитета по кадрам и вознаграждениям включают:
# 1. Усиление кадрового состава и повышение эффективности работы Наблюдательного совета.
# 2. Подготовка предложений по формированию эффективной системы вознаграждения членов Наблюдательного совета, исполнительных органов Банка и иных ключевых руководящих работников.
# 3. Формирование программ адаптации и профессионального развития членов Наблюдательного совета с учетом их индивидуальных потребностей.
# 4. Контроль за практической реализацией программ адаптации и профессионального развития.
# 5. Регулярная оценка деятельности членов исполнительных органов Банка, включая учет ESG-показателей.
# 6. Подготовка рекомендаций по кандидатуре куратора по вопросам ESG и устойчивого развития из состава Наблюдательного совета.
#
# ==================================================
# Question: Назови цели развития магазинов у дома у ритейлера Лента |
# Golden answer: Открытие более 500 магазинов в год; Прибыльный рост LFL-продаж; Синергия с "Лентой" |
# Pro Graph Answer: Целью развития магазинов у дома у ритейлера "Лента" является обеспечение удобства покупателей и удовлетворение их потребностей в продуктах питания. |
# Max Graph Answer: Цели развития магазинов у дома у ритейлера "Лента" включают:
#
# 1. Наращивание продаж.
# 2. Формирование центров прибыли.
# 3. Вклад в достижение целей устойчивого развития, включая ликвидацию голода (цель устойчивого развития ЦУР 2).
# 4. Учет онлайн-продаж как части общего объема продаж. |
# QA Answer GigaPro: Целями развития магазинов у дома у ритейлера "Лента" являются:
# 1. Открытие более 500 магазинов в год.
# 2. Прибыльный рост LFL-продаж на уровне лидеров формата или выше.
# 3. Лидерство по динамике LFL в домашних регионах.
# 4. Рост в новых регионах не ниже форматных конкурентов.
# 5. Сохранение высокого уровня рентабельности.
# 6. Реализация синергии с "Лентой", включая улучшение коммерческих условий, снижение затрат на логистику, повышение эффективности некоммерческих закупок, ускорение экспансии в регионах присутствия и выход в соседние регионы.
# 7. Адаптация CVP (ценностное предложение) для выхода в Москву и Санкт-Петербург.
#
# ==================================================
# Question: Сколько всего было продано Станций Ядекса ? |
# Golden answer: 9.6 млн с конца 2018 года |
# Pro Graph Answer: В предоставленной информации нет данных о количестве проданных станций Яндекса. |
# Max Graph Answer: Для ответа на вопрос о количестве проданных станций "Яндекса" необходимо предоставить соответствующую информацию. В предоставленных данных нет информации о продажах станций "Яндекса". |
# QA Answer GigaPro: В предоставленном контексте нет конкретной информации о количестве проданных устройств "Яндекс Станция".
#
# ==================================================
# Question: Ущерб государству от травмы одного человека ? |
# Golden answer: 8,2 млн рублей - средняя оценка ущерба для государства от смерти или тяжелых травм одного человека (данные ВШЭ за 2015 год) |
# Pro Graph Answer: Ущерб государству от травмы одного человека составляет 1 550 000 рублей. |
# Max Graph Answer: Ущерб государству от травмы одного человека не указан в предоставленной информации. |
# QA Answer GigaPro: Ущерб государству от травмы одного человека составляет в среднем 8,2 миллиона рублей (по данным ВШЭ за 2015 год).
#
# ==================================================
# Question: Как x5 боролся с ковидом? |
# Golden answer: Ранее Х5 Group полностью адаптировала свои процессы к условиям работы в пандемию коронавирусной инфекции. В 2022 году Компания продолжила принимать меры по противодействию распространению COVID-19 за счёт создания аналитических инструментов, позволяющих оперативно собирать данные по заболеваемости COVID-19 и вакцинации |
# Pro Graph Answer: X5 боролся с ковидом путем расширения сотрудничества с вузами и предоставления продовольственной помощи. |
# Max Graph Answer: Из предоставленной информации нельзя сделать вывод о том, как именно x5 боролся с ковидом. |
# QA Answer GigaPro: X5 Group активно боролась с пандемией COVID-19, полностью адаптируя свои процессы к работе в условиях пандемии. В 2022 году компания продолжала принимать меры по противодействию распространению COVID-19. Были созданы аналитические инструменты для сбора данных по заболеваемости COVID-19 и вакцинации, что позволило оперативно управлять рисками обеспечения персоналом. На объектах компании были размещены информационно-просветительские материалы о рисках заражения коронавирусной инфекцией.
#
# ==================================================
# Question: Какие цели развития у сети x5? |
# Golden answer: Лидерство на рынке продуктовой розницы. Фокус на эффективности. Цифровизация. Забота об обществе |
# Pro Graph Answer: nan |
# Max Graph Answer: nan |
# QA Answer GigaPro: Цели развития у сети X5 включают:
#
# 1. Сокращение удельных выбросов парниковых газов (Scope 1 + Scope 2) на 15% на 1 м² торговой площади по сравнению с 2019 годом через повышение энергоэффективности к 2025 году.
# 2. Поддержание уровня вовлеченности сотрудников на уровне не ниже 80% на фоне роста бизнеса к 2025 году.
# 3. Повышение знания и привлекательности бренда работодателя Х5 Group и брендов работодателя активов компании к 2025 году.
# 4. Доля возобновляемой и низкоуглеродной энергии, используемой в операционной деятельности Х5, составит 10% к 2025 году.
# 5. Упаковка товаров СТМ будет устойчивой на 60% к 2025 году.
# 6. Ежегодный прирост количества благополучателей программ продовольственной помощи на 10% год к году к 2025 году.
# 7. Программа «Островок безопасности» будет распространена на все магазины «Пятёрочка» и «Перекрёсток» к 2025 году.
# 8. Развитие программ помощи местным сообществам, включая программу «Центр местных сообществ» в «Пятёрочке», к 2025 году.
#
# ==================================================
# Question: Как в пятерочке борятся с инцидентами информационной безопасности ? |
# Golden answer: В Компании существует специализированное подразделение,которое осуществляет реагирование на инциденты информационной безопасности в режиме 24/7 — Ситуационный центр кибербезопасности |
# Pro Graph Answer: В предоставленной информации нет данных о том, как в "Пятерочке" борются с инцидентами информационной безопасности. |
# Max Graph Answer: В "Пятерочке" борьба с инцидентами информационной безопасности осуществляется посредством использования инструмента обратной связи и сотрудничества со Сбером. Сбер предоставляет образовательные кредиты и помогает устранять инциденты. Проект был начат в конце 2023 года и планируется его расширение на основе обратной связи от клиентов. |
# QA Answer GigaPro: В Пятерочке ведется активная работа по предотвращению инцидентов информационной безопасности. Для этого разработаны и проводятся регулярные курсы в области информационной безопасности для новых сотрудников и уже работающих специалистов. Особое внимание уделяется обучению пользователей, проводятся тестовые фишинговые рассылки с целью обучения правильному реагированию на угрозы. Также разрабатываются и внедряются политики по защите персональных данных клиентов, соответствующие требованиям российского законодательства.
#
# ==================================================
# Question: Какая стратегия развития у новатека? |
# Golden answer: Наращивание ресурсной базы Увеличение добычи углеводородов Устойчивое развитие(1) Сохранение низкого уровня затрат Оптимизация каналов маркетинга Создание конкурентоспособных и масштабируемых мощностей по производству СПГ
#  |
# Pro Graph Answer: Стратегия развития "Новатэка" не указана в предоставленной информации. |
# Max Graph Answer: nan |
# QA Answer GigaPro: Стратегия развития НОВАТЭКа заключается в создании и развитии конкурентоспособных мощностей по производству и реализации сжиженного природного газа (СПГ), а также в соблюдении принципов устойчивого развития, включающих высокий уровень социальной ответственности и современные стандарты в области экологической и промышленной безопасности.
#
# ==================================================
# Question: Какие экологические проекты у Новатэк на камчатке?  |
# Golden answer: Ключевым мероприятием в 2022 году стало участие в реализации подписанного в 2021 году соглашения с Кроноцким государственным заповедником о сотрудничестве с целью сохранения биологического разнообразия Камчатского края: проведены исследования и разработаны меры по сохранению и восстановлению численности популяции дикого северного оленя; проведен учет краснокнижных каланов у юго-восточного побережья Камчатки; начато изучение морских млекопитающих и среды их обитания в районе мыса Шипунский. |
# Pro Graph Answer: Из предоставленной информации нельзя сделать вывод о том, какие конкретно экологические проекты реализует компания "НоваТЭК" на Камчатке. |
# Max Graph Answer: На основе предоставленной информации невозможно ответить на этот вопрос. |
# QA Answer GigaPro: На Камчатке у Новатэка реализуются следующие экологические проекты:
#
# 1. Проведение исследований и разработка мер по сохранению и восстановлению численности популяции дикого северного оленя.
# 2. Проведение учета краснокнижных каланов у юго-восточного побережья Камчатки.
# 3. Начало изучения морских млекопитающих и среды их обитания в районе мыса Шипунский.
#
# ==================================================
# Question: Сколько подписчиков в яндекс плюс? |
# Golden answer: nan |
# Pro Graph Answer: nan |
# Max Graph Answer: Из предоставленной информации невозможно определить количество подписчиков в Яндекс Плюс. |
# QA Answer GigaPro: Количество подписчиков Яндекс Плюса составляет 30,4 миллиона на декабрь 2023 года.
#
# ==================================================
# Question: Сводка по роботам третьего поколения, которые занимаются доставкой |
# Golden answer: nan |
# Pro Graph Answer: nan |
# Max Graph Answer: Роботы третьего поколения, занимающиеся доставкой, оснащены съемной батареей, что позволяет им работать непрерывно. Кроме того, они способны ориентироваться даже в темное время суток. |
# QA Answer GigaPro: Сводка по роботам третьего поколения, которые занимаются доставкой, выглядит следующим образом:
#
# - Вмещают до 20 кг груза.
# - Оснащены съемной батареей для бесперебойной работы.
# - Передвигаются со скоростью 5-8 км/ч.
# - Уверенно ориентируются даже в темноте.
#
# ==================================================
# Question: кто развивает свою микрогенерацию? |
# Golden answer: nan |
# Pro Graph Answer: nan |
# Max Graph Answer: nan |
# QA Answer GigaPro: Развивают свою микрогенерацию активисты проекта "Земля касается каждого". Они установили первую общественную солнечную электростанцию на одной из учебных баз национального парка "Угра" в Калужской области.
#
# ==================================================
# Question: какую мощность будет выдавать станция? |
# Golden answer: nan |
# Pro Graph Answer: nan |
# Max Graph Answer: nan |
# QA Answer GigaPro: Станция будет выдавать мощность в 5 кВт при максимальном солнечном потоке.
#
# ==================================================
# Question: какую мощность потребляет семья в квартире? |
# Golden answer: nan |
# Pro Graph Answer: Приведенная информация не содержит данных о мощности, которую потребляет семья в квартире. |
# Max Graph Answer: Для того чтобы определить среднюю мощность, которую потребляет семья в квартире, нужно годовое потребление энергии разделить на количество часов в году.
#
# 1 год = 365 дней * 24 часа/день = 8760 часов
#
# Среднее годовое потребление семьи составляет от 3200 до 3500 кВт*ч. Возьмем среднее значение:
#
# (3200 + 3500) / 2 = 3350 кВт*ч
#
# Теперь разделим это число на количество часов в году:
#
# 3350 кВт*ч / 8760 часов ≈ 0,3823 кВт
#
# Таким образом, средняя мощность, которую потребляет семья в квартире, составляет примерно 0,38 кВт (или 380 Вт). |
# QA Answer GigaPro: Семья, проживающая в двухкомнатной квартире с электрической плитой, потребляет в год в среднем около 3200–3500 кВт⋅ч электроэнергии.
#
# ==================================================
# Question: кто такие муравьи солдаты |
# Golden answer: nan |
# Pro Graph Answer: nan |
# Max Graph Answer: nan |
# QA Answer GigaPro: Муравьи-солдаты — это разновидность муравьев, чья основная роль заключается в защите муравьиной семьи, включая матку или королев. Они обычно имеют крупные размеры и мощные челюсти, что позволяет им эффективно сражаться против врагов.
#
# ==================================================
# Question: как муравьи работают |
# Golden answer: nan |
# Pro Graph Answer: nan |
# Max Graph Answer: nan |
# QA Answer GigaPro: В контексте представленной информации нет прямого описания того, как именно муравьи "работают". Однако можно сделать выводы на основе общего описания муравьев. Рабочие муравьи, составляющие подавляющее большинство особей в муравьиной семье, занимаются заботой о семье. Они выполняют различные задачи, такие как сбор пищи, строительство гнезда, уход за потомством и защита колонии.
#
# ==================================================
# Question: в чем проявляется фокус на эффективность? |
# Golden answer: nan |
# Pro Graph Answer: Фокус на эффективность проявляется в адаптации коммерческого предложения под факторы, которые важны для целевых сегментов покупателей. |
# Max Graph Answer: Фокус на эффективность проявляется в том, что делается акцент на лучшее предложение в данный конкретный момент времени. |
# QA Answer GigaPro: Фокус на эффективность проявляется в нескольких аспектах:
#
# 1. Продолжение прироста торговых платежей.
# 2. Фокус на формате магазинов у дома "Пятерочка" и агрессивный рост "Чижика".
# 3. Эффективная реконструкция и удлиненный жизненный цикл магазинов в части обновления и ремонта оборудования.
# 4. Увеличение эффективности за счет высокой доходности (IRR >100%) цифровизации процессов.
# 5. Развитие логистики путем обновления парка грузовиков и открытия новых распределительных центров.
# 6. Повышение эффективности персонала за счет роста продуктивности через упрощение процессов и автоматизацию.
# 7. Оптимизация операционных затрат за счет экономии на масштабах бизнеса, кросс-форматных синергий и инициатив в области эффективности.
# 8. Рост доли СТМ и прямого импорта для дифференциации ассортимента и улучшения гросс-маржи.
#
# ==================================================
# Question: доля рынка в 2021 году? |
# Golden answer: nan |
# Pro Graph Answer: nan |
# Max Graph Answer: nan |
# QA Answer GigaPro: Доля рынка в 2021 году составила 76%.
#
# ==================================================

# %%
ask_graph_questions(questions)
# Out:
# Question: Сколько активных корпоративных клиентов ?
# True answer: Согласно отчету за 2023 год насчитывается 3,2 миллиона активных копроративных клиентов. |
# Max Graph Answer: 3,2 миллиона активных корпоративных клиентов.
#
# ==================================================
# Question: Какую награду присудило агентство нильсон репорт ?
# True answer: Агентство Nilson Report присудило две награды: #1 эквайер в Европе, #3 эквайер в мире. |
# Max Graph Answer: Агентство Nilson Report присудило следующие награды:
# - № 3 эквайер в мире;
# - № 1 эквайер в Европе.
#
# ==================================================
# Question: Какова доля Сбербанка в сегменте средств частных клиентов ?
# True answer: За 2023 год доля средств частных клиентов составила 43,9% |
# Max Graph Answer: Доля Сбербанка в сегменте средств частных клиентов составляет 43,9%.
#
# ==================================================
