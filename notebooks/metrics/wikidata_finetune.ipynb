# %% [markdown]
# # Fine-tuning E5 Embeddings on Wikidata
#
# Этот блокнот выполняет дообучение (fine-tuning) модели эмбеддингов E5 на данных Wikidata для улучшения метрик поиска.

# %%
import os
os.environ["WANDB_DISABLED"] = "true"  # Disable W&B logging to avoid API key error
import pickle
import torch
import gc
from torch.utils.data import DataLoader
from sentence_transformers import SentenceTransformer, InputExample, losses, models
from tqdm.auto import tqdm
import sys

IS_KAGGLE = os.path.exists('/kaggle/input')
if IS_KAGGLE:
    print("Running on Kaggle")
    DATA_BASE_PATH = '/kaggle/input/wikidata-big-sber'
    os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"
else:
    print("Running Locally")
    DATA_BASE_PATH = '../../wikidata_big'

device = 'cuda' if torch.cuda.is_available() else 'mps' if torch.backends.mps.is_available() else 'cpu'
print(f"Using device: {device}")

def clear_memory():
    gc.collect()
    if torch.cuda.is_available():
        torch.cuda.empty_cache()
    elif torch.backends.mps.is_available():
        torch.mps.empty_cache()
    print("Memory cleared")

clear_memory()
# Out:
# Using device: mps
# Memory cleared

# %%
import logging

# Настройка логирования для вывода Loss в поток вывода
logging.basicConfig(format='%(asctime)s - %(message)s',
                    datefmt='%Y-%m-%d %H:%M:%S',
                    level=logging.INFO,
                    handlers=[logging.StreamHandler(sys.stdout)])

# %%
DATA_PATH = os.path.join(DATA_BASE_PATH, 'kg/tkbc_processed_data/wikidata_big/')
ENT_TEXT_PATH = os.path.join(DATA_BASE_PATH, 'kg/wd_id2entity_text.txt')
REL_TEXT_PATH = os.path.join(DATA_BASE_PATH, 'kg/wd_id2relation_text.txt')

def load_pickle(name):
    with open(os.path.join(DATA_PATH, name), 'rb') as f:
        return pickle.load(f)

ent_to_id = load_pickle('ent_id')
rel_to_id = load_pickle('rel_id')
ts_to_id = load_pickle('ts_id')

id_to_ent = {v: k for k, v in ent_to_id.items()}
id_to_rel = {v: k for k, v in rel_to_id.items()}
id_to_ts = {v: str(k) for k, v in ts_to_id.items()}

train_data = load_pickle('train.pickle')
print(f"Loaded {len(train_data)} training quadruplets")

# Загрузка текстовых меток
def load_text_mapping(file_path):
    mapping = {}
    if os.path.exists(file_path):
        with open(file_path, 'r', encoding='utf-8') as f:
            for line in f:
                parts = line.strip().split('\t')
                if len(parts) >= 2:
                    mapping[parts[0]] = parts[1]
    return mapping

ent_labels = load_text_mapping(ENT_TEXT_PATH)
rel_labels = load_text_mapping(REL_TEXT_PATH)

print(f"Loaded {len(ent_labels)} entity labels and {len(rel_labels)} relation labels")

def get_label(id_str, mapping, default_val):
    return mapping.get(id_str, default_val)

def format_ts(ts_tuple):
    # (Year, Month, Day) -> "Year" or "Year-Month-Day"
    y, m, d = ts_tuple
    if m == 0 and d == 0:
        return str(y)
    return f"{y}-{m:02d}-{d:02d}"

ts_to_id_inv = {v: k for k, v in ts_to_id.items()}
# Out:
# Loaded 322988 training quadruplets
# Loaded 125725 entity labels and 203 relation labels

# %%
# Формируем тренировочные пары (Запрос, Положительный ответ)
train_samples = []

limit = 50000  # Увеличиваем лимит для стабильного фин-тюнинга
for row in tqdm(train_data[:limit], desc="Preparing samples"):
    s_id = id_to_ent[row[0]]
    r_id = id_to_rel[row[1]]
    o_id = id_to_ent[row[2]]
    t_tuple = ts_to_id_inv[row[3]]
    
    # Использование текстовых меток (нормальных имен)
    s_label = get_label(s_id, ent_labels, s_id)
    r_label = get_label(r_id, rel_labels, r_id)
    o_label = get_label(o_id, ent_labels, o_id)
    t_label = format_ts(t_tuple)
    
    # Task 1: Predict Object (Standard KG task)
    query_obj = f"query: {t_label}: {s_label} {r_label}"
    target_obj = f"passage: {o_label}"
    train_samples.append(InputExample(texts=[query_obj, target_obj]))
    
    # Task 2: Predict Time (The main goal: Temporal Reasoning)
    # Пример: "When did Albert Einstein live in Berlin?" -> "1914-1932"
    query_time = f"query: When did {s_label} {r_label} {o_label}?"
    target_time = f"passage: {t_label}"
    train_samples.append(InputExample(texts=[query_time, target_time]))

print(f"Created {len(train_samples)} InputExamples with robust temporal tasks")
# Out:
# Preparing samples:   0%|          | 0/20000 [00:00<?, ?it/s]
# Created 40000 InputExamples (Object + Time tasks)

# %%
model_name = 'intfloat/multilingual-e5-small'
word_embedding_model = models.Transformer(model_name)
pooling_model = models.Pooling(word_embedding_model.get_word_embedding_dimension())
model = SentenceTransformer(modules=[word_embedding_model, pooling_model], device=device)

train_dataloader = DataLoader(train_samples, shuffle=True, batch_size=16)
train_loss = losses.MultipleNegativesRankingLoss(model)

num_epochs = 3  # Поставили 3 эпохи для глубокого обучения
warmup_steps = int(len(train_dataloader) * num_epochs * 0.1)

clear_memory()
model.fit(
    train_objectives=[(train_dataloader, train_loss)],
    epochs=num_epochs,
    warmup_steps=warmup_steps,
    checkpoint_path='./checkpoints',
    checkpoint_save_total_limit=1,
    show_progress_bar=True
)

# Сохранение финальной модели
OUTPUT_PATH = '/kaggle/working/wikidata_finetuned' if IS_KAGGLE else '../../models/wikidata_finetuned'
model.save(OUTPUT_PATH)
print(f"Training finished! Model saved to {OUTPUT_PATH}")
# Out:
# 2026-01-27 17:37:45 - HTTP Request: HEAD https://huggingface.co/intfloat/multilingual-e5-small/resolve/main/adapter_config.json "HTTP/1.1 404 Not Found"
# 2026-01-27 17:37:45 - HTTP Request: HEAD https://huggingface.co/intfloat/multilingual-e5-small/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-01-27 17:37:45 - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/intfloat/multilingual-e5-small/c007d7ef6fd86656326059b28395a7a03a7c5846/config.json "HTTP/1.1 200 OK"
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: intfloat/multilingual-e5-small
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 2026-01-27 17:37:46 - HTTP Request: HEAD https://huggingface.co/intfloat/multilingual-e5-small/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-01-27 17:37:46 - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/intfloat/multilingual-e5-small/c007d7ef6fd86656326059b28395a7a03a7c5846/config.json "HTTP/1.1 200 OK"
# 2026-01-27 17:37:46 - HTTP Request: HEAD https://huggingface.co/intfloat/multilingual-e5-small/resolve/main/tokenizer_config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-01-27 17:37:46 - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/intfloat/multilingual-e5-small/c007d7ef6fd86656326059b28395a7a03a7c5846/tokenizer_config.json "HTTP/1.1 200 OK"
# 2026-01-27 17:37:46 - HTTP Request: HEAD https://huggingface.co/intfloat/multilingual-e5-small/resolve/main/tokenizer_config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-01-27 17:37:46 - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/intfloat/multilingual-e5-small/c007d7ef6fd86656326059b28395a7a03a7c5846/tokenizer_config.json "HTTP/1.1 200 OK"
# 2026-01-27 17:37:46 - HTTP Request: GET https://huggingface.co/api/models/intfloat/multilingual-e5-small/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 404 Not Found"
# 2026-01-27 17:37:46 - HTTP Request: GET https://huggingface.co/api/models/intfloat/multilingual-e5-small/tree/main?recursive=true&expand=false "HTTP/1.1 200 OK"
# 2026-01-27 17:37:47 - HTTP Request: GET https://huggingface.co/api/models/intfloat/multilingual-e5-small "HTTP/1.1 200 OK"
# Memory cleared
# Computing widget examples:   0%|          | 0/1 [00:00<?, ?example/s]
# /Users/nmuravya/.pyenv/versions/3.11.7/lib/python3.11/site-packages/torch/utils/data/dataloader.py:683: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
#     <div>
#
#       <progress value='56' max='2500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [  56/2500 03:32 < 2:40:19, 0.25 it/s, Epoch 0.02/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 11
#       9 # Обучение
#      10 clear_memory()
# ---> 11 model.fit(
#      12           checkpoint_path='../../models/checkpoints',
#      13           checkpoint_save_total_limit=1,train_objectives=[(train_dataloader, train_loss)],
#      14           epochs=1,
#      15           warmup_steps=100,
#      16           show_progress_bar=True)
#      18 # Сохранение модели
#      19 OUTPUT_PATH = '../../models/wikidata_finetuned'
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/sentence_transformers/fit_mixin.py:408, in FitMixin.fit(self, train_objectives, evaluator, epochs, steps_per_epoch, scheduler, warmup_steps, optimizer_class, optimizer_params, weight_decay, evaluation_steps, output_path, save_best_model, max_grad_norm, use_amp, callback, show_progress_bar, checkpoint_path, checkpoint_save_steps, checkpoint_save_total_limit, resume_from_checkpoint)
#     405         logger.warning(f"Checkpoint directory does not exist or is not a directory: {checkpoint_path}")
#     406         resume_from_checkpoint = None
# --> 408 trainer.train(resume_from_checkpoint=resume_from_checkpoint)
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/transformers/trainer.py:2174, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2172         hf_hub_utils.enable_progress_bars()
#    2173 else:
# -> 2174     return inner_training_loop(
#    2175         args=args,
#    2176         resume_from_checkpoint=resume_from_checkpoint,
#    2177         trial=trial,
#    2178         ignore_keys_for_eval=ignore_keys_for_eval,
#    2179     )
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/transformers/trainer.py:2536, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2529 context = (
#    2530     functools.partial(self.accelerator.no_sync, model=model)
#    2531     if i != len(batch_samples) - 1
#    2532     and self.accelerator.distributed_type != DistributedType.DEEPSPEED
#    2533     else contextlib.nullcontext
#    2534 )
#    2535 with context():
# -> 2536     tr_loss_step = self.training_step(model, inputs, num_items_in_batch)
#    2538 if (
#    2539     args.logging_nan_inf_filter
#    2540     and not is_torch_xla_available()
#    2541     and (torch.isnan(tr_loss_step) or torch.isinf(tr_loss_step))
#    2542 ):
#    2543     # if loss is nan or inf simply add the average of previous logged losses
#    2544     tr_loss = tr_loss + tr_loss / (1 + self.state.global_step - self._globalstep_last_logged)
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/transformers/trainer.py:3809, in Trainer.training_step(self, model, inputs, num_items_in_batch)
#    3806     return loss_mb.reduce_mean().detach().to(self.args.device)
#    3808 with self.compute_loss_context_manager():
# -> 3809     loss = self.compute_loss(model, inputs, num_items_in_batch=num_items_in_batch)
#    3811 del inputs
#    3812 if (
#    3813     self.args.torch_empty_cache_steps is not None
#    3814     and self.state.global_step % self.args.torch_empty_cache_steps == 0
#    3815 ):
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/sentence_transformers/trainer.py:434, in SentenceTransformerTrainer.compute_loss(self, model, inputs, return_outputs, num_items_in_batch)
#     428 if (
#     429     model == self.model_wrapped
#     430     and hasattr(loss_fn, "model")  # Only if the loss stores the model
#     431     and loss_fn.model != model  # Only if the wrapped model is not already stored
#     432 ):
#     433     loss_fn = self.override_model_in_loss(loss_fn, model)
# --> 434 loss = loss_fn(features, labels)
#     435 if isinstance(loss, dict):
#     436     self.track_loss_components(loss)
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/sentence_transformers/losses/MultipleNegativesRankingLoss.py:113, in MultipleNegativesRankingLoss.forward(self, sentence_features, labels)
#     111 def forward(self, sentence_features: Iterable[dict[str, Tensor]], labels: Tensor) -> Tensor:
#     112     # Compute the embeddings and distribute them to anchor and candidates (positive and optionally negatives)
# --> 113     embeddings = [self.model(sentence_feature)["sentence_embedding"] for sentence_feature in sentence_features]
#     115     return self.compute_loss_from_embeddings(embeddings, labels)
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/sentence_transformers/losses/MultipleNegativesRankingLoss.py:113, in <listcomp>(.0)
#     111 def forward(self, sentence_features: Iterable[dict[str, Tensor]], labels: Tensor) -> Tensor:
#     112     # Compute the embeddings and distribute them to anchor and candidates (positive and optionally negatives)
# --> 113     embeddings = [self.model(sentence_feature)["sentence_embedding"] for sentence_feature in sentence_features]
#     115     return self.compute_loss_from_embeddings(embeddings, labels)
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/sentence_transformers/SentenceTransformer.py:1175, in SentenceTransformer.forward(self, input, **kwargs)
#    1169             module_kwarg_keys = self.module_kwargs.get(module_name, [])
#    1170         module_kwargs = {
#    1171             key: value
#    1172             for key, value in kwargs.items()
#    1173             if key in module_kwarg_keys or (hasattr(module, "forward_kwargs") and key in module.forward_kwargs)
#    1174         }
# -> 1175     input = module(input, **module_kwargs)
#    1176 return input
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/sentence_transformers/models/Transformer.py:262, in Transformer.forward(self, features, **kwargs)
#     239 """
#     240 Forward pass through the transformer model.
#     241
#    (...)
#     258         - 'all_layer_embeddings': If the model outputs hidden states, contains embeddings from all layers
#     259 """
#     260 trans_features = {key: value for key, value in features.items() if key in self.model_forward_params}
# --> 262 outputs = self.auto_model(**trans_features, **kwargs, return_dict=True)
#     263 token_embeddings = outputs[0]
#     264 features["token_embeddings"] = token_embeddings
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/transformers/utils/generic.py:1002, in check_model_inputs.<locals>.wrapped_fn.<locals>.wrapper(self, *args, **kwargs)
#    1000             outputs = func(self, *args, **kwargs)
#    1001     else:
# -> 1002         outputs = func(self, *args, **kwargs)
#    1003 except TypeError as original_exception:
#    1004     # If we get a TypeError, it's possible that the model is not receiving the recordable kwargs correctly.
#    1005     # Get a TypeError even after removing the recordable kwargs -> re-raise the original exception
#    1006     # Otherwise -> we're probably missing `**kwargs` in the decorated function
#    1007     kwargs_without_recordable = {k: v for k, v in kwargs.items() if k not in recordable_keys}
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/transformers/models/bert/modeling_bert.py:696, in BertModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, cache_position, **kwargs)
#     679 embedding_output = self.embeddings(
#     680     input_ids=input_ids,
#     681     position_ids=position_ids,
#    (...)
#     684     past_key_values_length=past_key_values_length,
#     685 )
#     687 attention_mask, encoder_attention_mask = self._create_attention_masks(
#     688     attention_mask=attention_mask,
#     689     encoder_attention_mask=encoder_attention_mask,
#    (...)
#     693     past_key_values=past_key_values,
#     694 )
# --> 696 encoder_outputs = self.encoder(
#     697     embedding_output,
#     698     attention_mask=attention_mask,
#     699     encoder_hidden_states=encoder_hidden_states,
#     700     encoder_attention_mask=encoder_attention_mask,
#     701     past_key_values=past_key_values,
#     702     use_cache=use_cache,
#     703     cache_position=cache_position,
#     704     position_ids=position_ids,
#     705     **kwargs,
#     706 )
#     707 sequence_output = encoder_outputs.last_hidden_state
#     708 pooled_output = self.pooler(sequence_output) if self.pooler is not None else None
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/transformers/models/bert/modeling_bert.py:452, in BertEncoder.forward(self, hidden_states, attention_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, cache_position, **kwargs)
#     440 def forward(
#     441     self,
#     442     hidden_states: torch.Tensor,
#    (...)
#     449     **kwargs: Unpack[TransformersKwargs],
#     450 ) -> tuple[torch.Tensor] | BaseModelOutputWithPastAndCrossAttentions:
#     451     for i, layer_module in enumerate(self.layer):
# --> 452         hidden_states = layer_module(
#     453             hidden_states,
#     454             attention_mask,
#     455             encoder_hidden_states,  # as a positional argument for gradient checkpointing
#     456             encoder_attention_mask=encoder_attention_mask,
#     457             past_key_values=past_key_values,
#     458             cache_position=cache_position,
#     459             **kwargs,
#     460         )
#     462     return BaseModelOutputWithPastAndCrossAttentions(
#     463         last_hidden_state=hidden_states,
#     464         past_key_values=past_key_values if use_cache else None,
#     465     )
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/transformers/modeling_layers.py:93, in GradientCheckpointingLayer.__call__(self, *args, **kwargs)
#      90         logger.warning_once(message)
#      92     return self._gradient_checkpointing_func(partial(super().__call__, **kwargs), *args)
# ---> 93 return super().__call__(*args, **kwargs)
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/transformers/models/bert/modeling_bert.py:397, in BertLayer.forward(self, hidden_states, attention_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, cache_position, **kwargs)
#     387 def forward(
#     388     self,
#     389     hidden_states: torch.Tensor,
#    (...)
#     395     **kwargs: Unpack[TransformersKwargs],
#     396 ) -> tuple[torch.Tensor]:
# --> 397     self_attention_output, _ = self.attention(
#     398         hidden_states,
#     399         attention_mask,
#     400         past_key_values=past_key_values,
#     401         cache_position=cache_position,
#     402         **kwargs,
#     403     )
#     404     attention_output = self_attention_output
#     406     if self.is_decoder and encoder_hidden_states is not None:
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/transformers/models/bert/modeling_bert.py:326, in BertAttention.forward(self, hidden_states, attention_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, cache_position, **kwargs)
#     315 def forward(
#     316     self,
#     317     hidden_states: torch.Tensor,
#    (...)
#     323     **kwargs: Unpack[TransformersKwargs],
#     324 ) -> tuple[torch.Tensor]:
#     325     attention_mask = attention_mask if not self.is_cross_attention else encoder_attention_mask
# --> 326     attention_output, attn_weights = self.self(
#     327         hidden_states,
#     328         encoder_hidden_states=encoder_hidden_states,
#     329         attention_mask=attention_mask,
#     330         past_key_values=past_key_values,
#     331         cache_position=cache_position,
#     332         **kwargs,
#     333     )
#     334     attention_output = self.output(attention_output, hidden_states)
#     335     return attention_output, attn_weights
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/transformers/models/bert/modeling_bert.py:202, in BertSelfAttention.forward(self, hidden_states, attention_mask, past_key_values, cache_position, **kwargs)
#     199 if self.config._attn_implementation != "eager":
#     200     attention_interface = ALL_ATTENTION_FUNCTIONS[self.config._attn_implementation]
# --> 202 attn_output, attn_weights = attention_interface(
#     203     self,
#     204     query_layer,
#     205     key_layer,
#     206     value_layer,
#     207     attention_mask,
#     208     dropout=0.0 if not self.training else self.dropout.p,
#     209     scaling=self.scaling,
#     210     **kwargs,
#     211 )
#     212 attn_output = attn_output.reshape(*input_shape, -1).contiguous()
#     213 return attn_output, attn_weights
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/transformers/integrations/sdpa_attention.py:92, in sdpa_attention_forward(module, query, key, value, attention_mask, dropout, scaling, is_causal, **kwargs)
#      88     if attention_mask is not None and attention_mask.dtype != torch.bool:
#      89         # Convert to boolean type, making sdpa to force call FlashAttentionScore to improve performance.
#      90         attention_mask = torch.logical_not(attention_mask.bool()).to(query.device)
# ---> 92 attn_output = torch.nn.functional.scaled_dot_product_attention(
#      93     query,
#      94     key,
#      95     value,
#      96     attn_mask=attention_mask,
#      97     dropout_p=dropout,
#      98     scale=scaling,
#      99     is_causal=is_causal,
#     100     **sdpa_kwargs,
#     101 )
#     102 attn_output = attn_output.transpose(1, 2).contiguous()
#     104 return attn_output, None
#
# KeyboardInterrupt:
